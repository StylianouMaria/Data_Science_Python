# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
car_data = pd.read_csv('Cars93.csv')

# Inline indicates to present graphs as cell output
# read_csv returns a DataFrame, the file path is relative to that of your notebook.

# %%
print(car_data.columns)

car_data["Rev.per.mile"]
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')
# 0     2890
# 1     2335
# 2     2280
# 3     2535
# 4     2545
#       ...
# 88    2915
# 89    2685
# 90    2385
# 91    2215
# 92    2310
# Name: Rev.per.mile, Length: 93, dtype: int64

# %%
car_data.head(5)
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %% [markdown]
# #### We are able to see how many Manufacturers we have in the data by using the unique() function below:

# %%
car_data['Manufacturer'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrylser', 'Chrysler', 'Dodge', 'Eagle', 'Ford', 'Geo', 'Honda',
#        'Hyundai', 'Infiniti', 'Lexus', 'Lincoln', 'Mazda',
#        'Mercedes-Benz', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile',
#        'Plymouth', 'Pontiac', 'Saab', 'Saturn', 'Subaru', 'Suzuki',
#        'Toyota', 'Volkswagen', 'Volvo'], dtype=object)

# %% [markdown]
# ##### Using Group-by’s and Merges
# Group-by’s can be used to build groups of rows based on a specific feature in your dataset eg. the ‘Manufacturer’ categorical column.

# %%
group_by_Manufacturer = car_data.groupby(by=['Manufacturer'])

car_data_avg = round(group_by_Manufacturer.mean(),0)
car_data_avg
# Out:
# /var/folders/f_/s_7jgq1x1j14wsyfmg57w6c80000gn/T/ipykernel_65203/1917858339.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_data_avg = round(group_by_Manufacturer.mean(),0)
#                Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# Manufacturer
# Acura                 2.0       21.0   25.0       29.0      22.0         28.0
# Audi                  4.0       28.0   33.0       38.0      20.0         26.0
# BMW                   5.0       24.0   30.0       36.0      22.0         30.0
# Buick                 8.0       21.0   22.0       23.0      19.0         28.0
# Cadillac             10.0       35.0   37.0       40.0      16.0         25.0
# Chevrolet            16.0       16.0   18.0       20.0      20.0         28.0
# ...

# %% [markdown]
# ##### With the generated dataset above we are able to do better visualizations for the data set

# %%
# Since all the columns in car_data_count are the same, we will use just the 
# first column as the rest yield the same result. iloc allows us to take all 
# the rows and the zeroth column.

car_data_count_series = car_data_avg.iloc[5:5,1]


## we will assemble a DataFrame of only the relevant features to plot  
features_of_interest = pd.DataFrame({'EngineSize': car_data_avg['EngineSize'],
                                     'Passengers': car_data_avg['Passengers'],
                                   }
                                   )

## Let us plot a few of the manufactures for visibility
features_of_interest = features_of_interest.iloc[:10,]
features_of_interest.plot(kind='bar')
# Out:
# <Axes: xlabel='Manufacturer'>

# %% [markdown]
# #### Stacked bar graph

# %%
features_of_interest.plot.bar(stacked=True)
#plot.bar() gives a normal graph
# Out:
# <Axes: xlabel='Manufacturer'>

# %%
#### Hosrizontal bar graph

# %%
features_of_interest.plot.barh(stacked=True)
#plot.barh prints a horizontal bar chart

# %% [markdown]
# #### Want to try pie charts? Lets do it

# %% [markdown]
# ##### Lets prepare some data. We can create a pie chart to show the population of categorical variables

# %%
# group by passengers 
group_by_Passengers = car_data.groupby(by=['Passengers'])

car_typePassengers = group_by_Passengers.count()

# get first column
car_typePassengers = pd.DataFrame(car_typePassengers.iloc[:,0])

car_typePassengers.rename(columns={'Manufacturer': 'Passengers'}, inplace=True)

car_typePassengers.plot.pie(subplots=True,figsize=(8, 8))
# Out:
# array([<Axes: ylabel='Unnamed: 0'>], dtype=object)

# %%
# group by Type 
group_by_Type = car_data.groupby(by=['Type'])

car_typecount = group_by_Type.count()

car_typecount = pd.DataFrame(car_typecount.iloc[:,0])

car_typecount.rename(columns={'Manufacturer': 'Type'}, inplace=True)

car_typecount.plot.pie(subplots=True,figsize=(8, 8))
# Out:
# array([<Axes: ylabel='Unnamed: 0'>], dtype=object)

# %%
# Group by Airbags
group_by_AirBags = car_data.groupby(by=['AirBags'])

car_AirBagscount = group_by_AirBags.count()

car_AirBagscount = pd.DataFrame(car_AirBagscount.iloc[:,0])

car_AirBagscount.rename(columns={'Manufacturer': 'Airbags'}, inplace=True)


car_AirBagscount.plot.pie(subplots=True,figsize=(8, 8))
# Out:
# array([<Axes: ylabel='Unnamed: 0'>], dtype=object)

# %% [markdown]
# Create a box plot for the revs per mile for the Audi, Hyundai, Suzuki and Toyota car manufacturers. Which of these manufacturers has the car with the highest revs per mile?

# %%
# Filter the dataset for the specified manufacturers
selected_manufacturers = ['Audi', 'Hyundai', 'Suzuki', 'Toyota']
filtered_data = car_data[car_data['Manufacturer'].isin(selected_manufacturers)]

# Create a box plot
plt.figure(figsize=(10, 6))  # Set the figure size
plt.boxplot([filtered_data[filtered_data['Manufacturer'] == manufacturer]['Rev.per.mile'] for manufacturer in selected_manufacturers],
            labels=selected_manufacturers)
plt.title('Box Plot of Revs per Mile by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Rev per Miles')

# Show the plot
plt.show()

#df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
#df.plot.box()

# %% [markdown]
# Create a histogram of MPG in the city. On the same axis, show a histogram of MPG on the highway. Is it generally more fuel efficient to drive in the city or the highway?

# %%
MPG_city_highway = car_data[["MPG.city", "MPG.highway"]]
MPG_city_highway
# Out:
#     MPG.city  MPG.highway
# 0         25           31
# 1         18           25
# 2         20           26
# 3         19           26
# 4         22           30
# ..       ...          ...
# 88        17           21
# 89        21           30
# 90        18           25
# 91        21           28
# 92        20           28
#
# [93 rows x 2 columns]

# %%
MPG_city_highway.plot.hist(alpha = 0.5, bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure()

#Create the first histogram MPG.city
plt.subplot(2, 1, 1)
sns.histplot(MPG_city_highway["MPG.city"], fill = True, bins = 20 )
plt.xlabel('MPG.city')
plt.ylabel('Frequency')
plt.title('Histogram of MPG.city')

#Create the first histogram MPG.highway
plt.subplot(2, 1, 2)
sns.histplot(MPG_city_highway["MPG.highway"], fill = True, bins = 20 )
plt.xlabel('MPG.highway')
plt.ylabel('Frequency')
plt.title('Histogram of MPG.highway')

# Add a caption for the second histogram
plt.text(0.5, -0.5, 'Figure: Miles per gallon consumed when driving within city (histogram no.1) vs highway (histogram no.2). It is generally more fuel efficient to drive into highways.', transform=plt.gca().transAxes, ha='center')

# Adjust the layout
plt.tight_layout()

# Show the histograms
plt.show()
# Out:
# /var/folders/f_/s_7jgq1x1j14wsyfmg57w6c80000gn/T/ipykernel_67426/3984741307.py:21: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# Create a lineplot showing the relationship between the Wheelbase and turning circle. What is this relationship? What happens when the wheelbase gets larger?

# %%
Wheelbase = car_data["Wheelbase"]
Turn_circle = car_data["Turn.circle"]

plt.figure()

#Create the first lineplot of Whellbase vs Turn.circle:
sns.lineplot(car_data, x = "Wheelbase", y = "Turn.circle")

# Add a caption for lineplot
plt.text(0.5, -0.5, 'Relationship between the Wheelbase and turning circle', transform=plt.gca().transAxes, ha='center')

# Adjust the layout
plt.tight_layout()

# Show the lineplot
plt.show()

# %% [markdown]
# •Although there are flactuations, when wheelbase is getting larger the turn.circles increase.

# %% [markdown]
# Create a bar plot showing the mean horsepower for each car Type (Small, Midsize, etc.). Does a larger car mean more horsepower?

# %%
#car_data["Horsepower"]
#car_data["Type"]

#group_by_Type = car_data.groupby(by=['Type'])

#car_typecount = group_by_Type.count()

figure = sns.barplot(car_data, 
                     x = "Type",
                     y = "Horsepower",
                     errorbar=None,                
                     ) #u can include errorbars errorbar="sd",color= "gray"

figure.bar_label(figure.containers[0], fontsize=10)


# Add labels and title
plt.xlabel('Car Types')
plt.ylabel('Horsepower')
plt.title('Boxplot of Values from Smaller to Larger')

# Show the plot
plt.show()

# %% [markdown]
# •Smaller car type has deffinitly lower horsepower compared to the large. However, midsize and largesize car can have similar hoersepower.

# %% [markdown]
# Create a pie chart for the respective engine sizes. Which engine size seems to be the most popular?

# %%
#Pie chart can be created oly wiht malplotlip and not seaborn
car_data["EngineSize"]
# Create a pie chart
EngineSize = car_data.groupby(["EngineSize"])["EngineSize"].sum()
EngineSize.plot.pie(subplots=True,figsize=(8, 8))

# Add a title
plt.title('Engine Size of Cars')

# Display the chart
plt.show()

# %% [markdown]
# • Engine sise 2.2, 3 and 3.8 are the most popular.
